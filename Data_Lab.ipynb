# %%
#Create and Write to a File 
from pathlib import Path

student_id = "TUPM-24-2017"
student_name = "Arjames E. Kinilitan"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
documents_path.mkdir(parents=True, exist_ok=True)

file_path = documents_path / f"intro_{student_id}.txt"
file_path.write_text(f"Welcome {student_name} (ID: {student_id}) to File Handling in Python!")

print(f"File created and text written at: {file_path}")
# Out:
# File created and text written at: C:\Users\Reno\Documents\Activity_5_Files\intro_TUPM-24-2017.txt

# %%
# Read file Content 
from pathlib import Path

student_id = "TUPM-24-2017"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
file_path = documents_path / f"intro_{student_id}.txt"

content = file_path.read_text()
print(content)
# Out:
# Welcome Arjames E. Kinilitan (ID: TUPM-24-2017) to File Handling in Python!

# %%
# Append to a file 
from pathlib import Path

student_id = "TUPM-24-2017"

file_path = Path.home() / "Documents" / "Activity_5_Files"
file_path = documents_path / f"intro_{student_id}.txt"
with file_path.open("a") as f:

   f.write("\nThis is a new line.")
print(f"Line append to: {file_path}")
# Out:
# Line append to: C:\Users\Reno\Documents\Activity_5_Files\intro_TUPM-24-2017.txt

# %%
# Write MUltiple Lines 
from pathlib import Path

student_id = "TUPM-24-2017"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
file_path = documents_path / f"lines_{student_id}.txt"

lines = ["Line 1", "Line 2", "Line 3"]
with file_path.open("w") as f:
    f.write("\n".join(lines))
print(f"Multiple lines written to: {file_path}")
# Out:
# Multiple lines written to: C:\Users\Reno\Documents\Activity_5_Files\lines_TUPM-24-2017.txt

# %%
from pathlib import Path

student_id = "TUPM-24-2017"

file_path =  Path.home() / "Documents" / "Activity_5_Files" /  f"lines_{student_id}.txt"

with file_path.open("r") as f:
    for line in f:
        print(line.strip())
# Out:
# Line 1
# Line 2
# Line 3

# %%
from pathlib import Path

student_id = "TUPM-24-2017"
student_name = "Arjames E. Kinilitan"

file_path = Path.home() / "Documents" / "Activity_5_Files" /  f"lines_{student_id}.txt"

text = file_path.read_text()
word_count = len(text.split())

print(f"{student_name} (ID: {student_id} - Word count in file '{file_path.name}': {word_count})")
# Out:
# Arjames E. Kinilitan (ID: TUPM-24-2017 - Word count in file 'lines_TUPM-24-2017.txt': 6)

# %%
from pathlib import Path 
 
student_id = "TUPM-24-2017" 
student_name = "Arjames E. Kinilitan" 
 
documents_path = Path.home() / "Documents" / "Activity_5_Files" 
documents_path.mkdir(parents=True, exist_ok=True) 
 
file_path = documents_path / f"intro_{student_id}.txt" 
file_path.write_text(f"Welcome {student_name} (ID: {student_id}) to File Handling in Python!") 
 
print(f"File created and text written at: {file_path}") 
 
#Cell 2: Copy File
import shutil 
from pathlib import Path 
 
student_id = "TUPM-24-2017" 
documents_path = Path.home() / "Documents" / "Activity_5_Files" 
 
# Define source and destination 
src = documents_path / f"intro_{student_id}.txt" 
dst = documents_path / f"intro_copy_{student_id}.txt" 
 
# Copy file shutil.copy(src, dst) 
print(f"File copied successfully from {src.name} to {dst.name}.")
# Out:
# File created and text written at: C:\Users\Reno\Documents\Activity_5_Files\intro_TUPM-24-2017.txt
# File copied successfully from intro_TUPM-24-2017.txt to intro_copy_TUPM-24-2017.txt.

# %%
from pathlib import Path

student_id = "tUPM-24-2017"

documents_path = Path.home() / "Documents" / "Activity_5_Files" 

old_file = documents_path / f"intro_copy_{student_id}.txt"
new_file = documents_path / f"intro_renamed_{student_id}.txt"

old_file = documents_path / f"intro_{student_id}.txt"
print(f"File rename successfully from {old_file.name} to {new_file.name}")
# Out:
# File rename successfully from intro_tUPM-24-2017.txt to intro_renamed_tUPM-24-2017.txt

# %%
from pathlib import Path

student_id = "TUPM-24-2017"

documents_path = Path.home() / "Documents" / "Activity_5_Files" 
file_path = documents_path / f"intro_renamed_{student_id}.txt"

if file_path.exists():
    file_path.unlink()
    print(f"File deleted successfully from: {file_path}")
else:
    print(f"No file found to delete at: {file_path}")
# Out:
# No file found to delete at: C:\Users\Reno\Documents\Activity_5_Files\intro_renamed_TUPM-24-2017.txt

# %%
from pathlib import Path

student_id = "TUPM-24-2017"

documents_path = Path.home() / "Documents" / "Activity_5_Files" 
new_dir = documents_path / f"data_{student_id}"

new_dir.mkdir(parents=True, exist_ok=True)

print(f"Subdirectory created at: {new_dir}")
# Out:
# Subdirectory created at: C:\Users\Reno\Documents\Activity_5_Files\data_TUPM-24-2017

# %%
import json
from pathlib import Path

student_id = "TUPM-24-2017"

documents_path = Path.home() / "Documents" / "Activity_5_Files" 
data_dir = documents_path / f"data_{student_id}"
data_dir.mkdir(parents=True, exist_ok=True)

data = {"name": "Arjames E. Kinilitan", "age": 21, "course": "Python Programming"}

file_path = data_dir / f"student_{student_id}.json"
with file_path.open("w") as f:
    json.dump(data, f, indent=4)

print(f"JSON file written at: {file_path}")
# Out:
# JSON file written at: C:\Users\Reno\Documents\Activity_5_Files\data_TUPM-24-2017\student_TUPM-24-2017.json

# %%
import json
from pathlib import Path{'name': 'Arjames E. Kinilitan', 'age': 21, 'course': 'Python Programming'}

student_id = "TUPM-24-2017"

documents_path = Path.home() / "Documents" / "Activity_5_Files" / f"data_{student_id}" / f"student_{student_id}.json"

with file_path.open("r") as f:
    data = json.load(f)

print(data)
# Out:
# {'name': 'Arjames E. Kinilitan', 'age': 21, 'course': 'Python Programming'}

# %%
import csv
from pathlib import Path

student_id = "TUPM-24-2017" 
student_name = "Arjames E. Kinilitan" 

documents_path = Path.home() / "Documents" / "Activity_5_Files"
file_path = documents_path / f"student_{student_id}.csv"

rows = [
    ["Name", "Student ID", "Score"],
    ["Anna", "2025-1001", 90],
    [student_name, student_id, 95]
]

with file_path.open("w", newline='') as f:
    writer = csv.writer(f)
    writer.writerows(rows)

print(f"CSV file created at: {file_path}")
# Out:
# CSV file created at: C:\Users\Reno\Documents\Activity_5_Files\student_TUPM-24-2017.csv

# %%
import csv
from pathlib import Path

student_id = "TUPM-24-2017"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"student_{student_id}.csv"

with file_path.open("r") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Student ID', 'Score']
# ['Anna', '2025-1001', '90']
# ['Arjames E. Kinilitan', 'TUPM-24-2017', '95']

# %%
from pathlib import Path

student_id = "TUPM-24-2017"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"missing_file_{student_id}.txt"


print(file_path.read_text())
except FileNotFoundError:
print(f"File not found for Student ID: {student_id}")
# Out:
#   Cell In[47], line 9
#     except FileNotFoundError:
#     ^
# SyntaxError: invalid syntax

# %%
# Count .txt Files 
from pathlib import Path 
 
# Personal details 
student_id = "TUPM-24-2017" 
 
# Define directory path 
documents_path = Path.home() / "Documents" / "Activity_5_Files" 
 
# Find all .txt files in the directory 
txt_files = list(documents_path.glob("*.txt")) 
 
# Display count and file names print(f"Student ID: {student_id}") 
print(f"Found {len(txt_files)} .txt files in {documents_path}") 
for file in txt_files:     print(file.name)
# Out:
# Found 2 .txt files in C:\Users\Reno\Documents\Activity_5_Files
# intro_TUPM-24-2017.txt
# lines_TUPM-24-2017.txt

# %%
# File Metadata import os import time 
from pathlib import Path 
 
# Personal details student_id = "2025-XXXX" 
 
# Define file path 
file_path = Path.home() / "Documents" / "Activity_5_Files" / f"intro_{student_id}.txt" 
 
# Retrieve and display file metadata 
if file_path.exists(): 
    stat = file_path.stat() 
    print(f"Student ID: {student_id}")     
    print(f"File: {file_path.name}")     
    print(f"Size: {stat.st_size} bytes") 
    print(f"Last Modified: {time.ctime(stat.st_mtime)}") 
else:     
    print(f"File {file_path.name} not found for Student ID: {student_id}")
# Out:
# Student ID: TUPM-24-2017
# File: intro_TUPM-24-2017.txt
# Size: 75 bytes
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 15
#      13     print(f"File: {file_path.name}")
#      14     print(f"Size: {stat.st_size} bytes")
# ---> 15     print(f"Last Modified: {time.ctime(stat.st_mtime)}")
#      16 else:
#      17     print(f"File {file_path.name} not found for Student ID: {student_id}")
#
# NameError: name 'time' is not defined

# %%
from pathlib import Path 
 
student_id = "TUPM-24-2017" 
 
# Define file path 
file_path = Path.home() / "Documents" / "Activity_5_Files" / f"lines_{student_id}.txt" 
 
# Ensure file exists before reading 
if not file_path.exists():     
    sample_lines = ["Line 1", "Line 2", "Line 3"]     
    file_path.write_text("\n".join(sample_lines))     
    print(f"Sample file created for Student ID: {student_id}") 
 
# Read, process, and rewrite the file with numbered uppercase lines 
lines = file_path.read_text().splitlines() 
with file_path.open("w") as f:     
      for i, line in enumerate(lines, 1): 
        f.write(f"{i}: {line.upper()}\n")  
        
print(f"Lines formatted and updated in file: {file_path}")
# Out:
# Lines formatted and updated in file: C:\Users\Reno\Documents\Activity_5_Files\lines_TUPM-24-2017.txt

# %%
from pathlib import Path 
 
student_id = "tupm-24-2017" 
 
# Define file path 
file_path = Path.home() / "Documents" / "Activity_5_Files" / f"lines_{student_id}.txt" 
 
# Ensure file exists before processing 
if not file_path.exists():     
    sample_lines = ["Line 1", "Line 2", "Line 3"]     
    file_path.write_text("\n".join(sample_lines))     
    print(f"Sample file created for Student ID: {student_id}") 
 
# Read, reverse, and overwrite the file lines = file_path.read_text().splitlines() lines.reverse()
with file_path.open("w") as f: 
    f.write("\n".join(lines))  
    print(f"File lines reversed for Student ID: {student_id}")
# Out:
# File lines reversed for Student ID: tupm-24-2017

# %%
from pathlib import Path 
 
student_id = "TUPM-24-2017" 
 
# Define file paths 
documents_path = Path.home() / "Documents" / "Activity_5_Files" 
f1 = documents_path / f"intro_{student_id}.txt" 
f2 = documents_path / f"lines_{student_id}.txt" 
merged = documents_path / f"merged_{student_id}.txt" 
 
# Ensure both source files exist 
if not f1.exists():     
    f1.write_text(f"Welcome {student_id} to File Handling in Python!")     
    print(f"Sample intro file created for Student ID: {student_id}") 
if not f2.exists():     
    f2.write_text("Line 1\nLine 2\nLine 3")     
    print(f"Sample lines file created for Student ID: {student_id}") 
 
# Merge contents of both files 
with merged.open("w") as mf:     
    mf.write(f1.read_text())     
    mf.write("\n") 
    mf.write(f2.read_text()) 

print(f"Files merged successfully for Student ID: {student_id}")
# Out:
# Files merged successfully for Student ID: TUPM-24-2017
